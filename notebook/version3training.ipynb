# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.12

# %% [markdown]
# # 2. Keypoints using MP Holistic
#
# Reference: https://google.github.io/mediapipe/solutions/holistic.html

# %%
# Use Holistic Models for detections
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities


# Make keypoint detection, model can only detect in RGB
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB as model can only detect in RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Use Model to make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def draw_landmarks(image, results): # draw landmarks for each image/frame
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections
    
def draw_styled_landmarks(image, results): # draw landmarks for each image/frame, fix colour of landmark drawn
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
# Open Computer Webcam using opencv
# Use computer webcam
cap = cv2.VideoCapture(0)
# Set mediapipe model 

while cap.isOpened(): #open webcam
    # Read feed
    ret, frame = cap.read()
    # Show to screen
    cv2.imshow('OpenCV Feed: Hold Q to Quit', frame)
    # Break gracefully
    if cv2.waitKey(10) & 0xFF == ord('q'): #press q to quit
        break
cap.release() #release webcam
cv2.destroyAllWindows()

# %%
# use computer webcam and make keypoint detections
cap = cv2.VideoCapture(0)

# Set mediapipe model configurations
min_detection_confidence = 0.5
min_tracking_confidence= 0.5

with mp_holistic.Holistic(min_detection_confidence=min_detection_confidence, min_tracking_confidence=min_tracking_confidence) as holistic:
    while cap.isOpened():
        # Read feed
        ret, frame = cap.read()

        # Make detections by calling our function
        image, results = mediapipe_detection(frame, holistic) #mediapipe_detection(image, model) 
        #print(results)
        #print(results.face_landmarks)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # Show to screen
        cv2.imshow('OpenCV Feed: Hold Q to Quit', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'): #press q to quit
            break
            
    cap.release() #release webcam
    cv2.destroyAllWindows()

# %%
#show last frame with keypoints drawn using draw styled landmarks
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
# call helper function to draw landmarks
draw_landmarks(frame, results)
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values to be used for our model training

# %%
#Show length of landmarks x,y,z spatial coordinates for right hand pose
len(results.right_hand_landmarks.landmark)
# Out:
# 21

# %%
# Show Results of landmark x,y,z spatial coordinates for face landmarks
print('Length of face landmarks:',len(results.face_landmarks.landmark))
print('Results Type:',type(results.face_landmarks))
print('Face landmarks Results:',results.face_landmarks)

# Convert facelandmarks to numpy array
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark])if results.face_landmarks else np.zeros(468*3)
print(face)
# Out:
# Length of face landmarks: 468
# Results Type: <class 'mediapipe.framework.formats.landmark_pb2.NormalizedLandmarkList'>
# Face landmarks Results: landmark {
#   x: 0.594624
#   y: 0.64530826
#   z: -0.02778087
# }
# landmark {
#   x: 0.6022281
#   y: 0.6052287
#   z: -0.045721978
# }
# landmark {
#   x: 0.59870166
#   y: 0.61954206
#   z: -0.02568405
# }
# landmark {
#   x: 0.59867597
#   y: 0.5689699
#   z: -0.032871667
# }
# landmark {
#   x: 0.6040242
#   y: 0.5933058
#   z: -0.04800582
# }
# landmark {
#   x: 0.6055409
#   y: 0.57934815
#   z: -0.043868683
# }
# landmark {
#   x: 0.6081259
#   y: 0.54789543
#   z: -0.018407172
# }
# landmark {
#   x: 0.5441138
#   y: 0.5373014
#   z: 0.010559215
# }
# landmark {
#   x: 0.611287
#   y: 0.52056134
#   z: -0.010974237
# }
# landmark {
#   x: 0.61349684
#   y: 0.5048522
#   z: -0.011684383
# }
# landmark {
#   x: 0.6196969
#   y: 0.53372616
#   z: 0.004752643
# }
# landmark {
#   x: 0.6590862
#   y: 0.53494567
#   z: 0.006522244
# }
# landmark {
#   x: 0.6680799
#   y: 0.5391705
#   z: 0.01087847
# }
# landmark {
#   x: 0.6735167
#   y: 0.5463679
#   z: 0.016728975
# }
# landmark {
#   x: 0.6736082
#   y: 0.56922823
#   z: 0.029039377
# }
# landmark {
#   x: 0.68538797
#   y: 0.6054237
#   z: 0.06736414
# }
# landmark {
#   x: 0.6666684
#   y: 0.5828646
#   z: 0.020915091
# }
# landmark {
#   x: 0.6585647
#   y: 0.5836189
#   z: 0.014984159
# }
# landmark {
#   x: 0.64837235
#   y: 0.5811006
#   z: 0.010508242
# }
# landmark {
#   x: 0.63864344
#   y: 0.5759414
#   z: 0.007916634
# }
# landmark {
#   x: 0.63120764
#   y: 0.5697429
#   z: 0.0072856876
# }
# landmark {
#   x: 0.62636864
#   y: 0.5640353
#   z: 0.006347315
# }
# landmark {
#   x: 0.6810603
#   y: 0.6084851
#   z: 0.09927
# }
# landmark {
#   x: 0.6231251
#   y: 0.61812687
#   z: -0.019864576
# }
# landmark {
#   x: 0.6184325
#   y: 0.5801937
#   z: -0.025499366
# }
# landmark {
#   x: 0.61451125
#   y: 0.6070343
#   z: -0.039928652
# }
# landmark {
#   x: 0.60844755
#   y: 0.61202955
#   z: -0.037279278
# }
# landmark {
#   x: 0.613755
#   y: 0.6093456
#   z: -0.035920925
# }
# landmark {
#   x: 0.61995554
#   y: 0.62133694
#   z: -0.017550532
# }
# landmark {
#   x: 0.60716087
#   y: 0.61245996
#   z: -0.039664272
# }
# landmark {
#   x: 0.60542136
#   y: 0.6154929
#   z: -0.030071013
# }
# landmark {
#   x: 0.6277753
#   y: 0.55602163
#   z: 0.010923661
# }
# landmark {
#   x: 0.6230436
#   y: 0.5562835
#   z: 0.005265604
# }
# landmark {
#   x: 0.62064856
#   y: 0.55629396
#   z: -0.00090800464
# }
# landmark {
#   x: 0.66531223
#   y: 0.56241643
#   z: 0.019271195
# }
# landmark {
#   x: 0.67043155
#   y: 0.55786467
#   z: 0.020153277
# }
#
# [[ 0.59462398  0.64530826 -0.02778087]
#  [ 0.60222811  0.60522872 -0.04572198]
#  [ 0.59870166  0.61954206 -0.02568405]
#  ...
#  [ 0.62064856  0.55629396 -0.000908  ]
#  [ 0.66531223  0.56241643  0.01927119]
#  [ 0.67043155  0.55786467  0.02015328]]

# %%
# Show Pose Connection Results
print('Pose Connection Results:',mp_holistic.POSE_CONNECTIONS)

# Get the landmarks x,y,z coordinates
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)
print(pose)
# Out:
# Pose Connection Results: frozenset({(15, 21), (16, 20), (18, 20), (3, 7), (14, 16), (23, 25), (28, 30), (11, 23), (27, 31), (6, 8), (15, 17), (24, 26), (16, 22), (4, 5), (5, 6), (29, 31), (12, 24), (23, 24), (0, 1), (9, 10), (1, 2), (0, 4), (11, 13), (30, 32), (28, 32), (15, 19), (16, 18), (25, 27), (26, 28), (12, 14), (17, 19), (2, 3), (11, 12), (27, 29), (13, 15)})
# [array([ 0.60383284,  0.57755452, -0.66478658,  0.99996322]), array([ 0.62611365,  0.53191322, -0.61061668,  0.99989229]), array([ 0.63809007,  0.53583562, -0.61048758,  0.99987108]), array([ 0.65132535,  0.54080307, -0.61046422,  0.9998697 ]), array([ 0.58587122,  0.52218008, -0.60630018,  0.99991888]), array([ 0.56909835,  0.52008247, -0.60566449,  0.99992263]), array([ 0.55345064,  0.51918179, -0.60578799,  0.99994117]), array([ 0.6668995 ,  0.57744718, -0.30102044,  0.99986619]), array([ 0.52265102,  0.55619806, -0.25944865,  0.9999426 ]), array([ 0.61838186,  0.64159554, -0.55761111,  0.99993473]), array([ 0.55955726,  0.6353575 , -0.54733896,  0.99994749]), array([ 0.75721323,  0.89269555, -0.14544734,  0.99793541]), array([ 0.39747041,  0.84542984, -0.17586815,  0.99961519]), array([ 0.86456758,  1.21387792, -0.05373771,  0.37714696]), array([ 0.22425005,  1.20161104, -0.62374127,  0.95001471]), array([ 0.90021551,  1.49804771, -0.09405232,  0.18239582]), array([ 0.32617709,  0.83706248, -1.34454226,  0.97583139]), array([ 0.93190652,  1.59014738, -0.12217148,  0.24517016]), array([ 0.31413227,  0.7070511 , -1.495857  ,  0.96952873]), array([ 0.89661121,  1.58280611, -0.15096506,  0.34646526]), array([ 0.34684414,  0.68626207, -1.43334544,  0.97270018]), array([ 0.87115335,  1.55404866, -0.11760174,  0.38562509]), array([ 0.36388618,  0.74411923, -1.346174  ,  0.97059017]), array([ 6.79967284e-01,  1.51346219e+00, -5.47655225e-02,  4.46217571e-04]), array([4.23384845e-01, 1.50794518e+00, 5.87402806e-02, 6.17247599e-04]), array([ 6.63957357e-01,  2.05840135e+00, -1.87346667e-01,  2.68026954e-04]), array([4.31896061e-01, 2.06057310e+00, 9.38723832e-02, 2.42431081e-04]), array([6.58060253e-01, 2.54429555e+00, 2.53218710e-01, 2.72272300e-05]), array([4.36077267e-01, 2.53322268e+00, 4.32283819e-01, 5.48413209e-06]), array([6.62209153e-01, 2.61371851e+00, 2.60728925e-01, 1.26222612e-05]), array([4.29604053e-01, 2.59806132e+00, 4.56376165e-01, 7.06320179e-06]), array([ 6.28345370e-01,  2.69231009e+00, -2.61637151e-01,  1.78122136e-05]), array([ 4.66777027e-01,  2.69416976e+00, -7.73528144e-02,  2.14741540e-05])]

# %%
# Using list comprehension to extract landmark results if landmark for body part is detected, else replace it with a blank array of zeros of the same shape for each body part    
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
print(pose.shape)
print(face.shape)
print(lh.shape)
print(rh.shape)
# Out:
# (132,)
# (1404,)
# (63,)
# (63,)

# %%
# Define extract keypoint function and convert to numpy array to be saved
# Exculde face keypoints
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    #face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    #return np.concatenate([pose, face, lh, rh]) # concatenate all the keypoints that are flattened
    return np.concatenate([pose, lh, rh])

result_test = extract_keypoints(results)

# %%
extract_keypoints(results).shape
# Out:
# (258,)

# %%
# Total number of coordinates in results (pose, left hand and right hand)
33*4 + 21*3 + 21*3
# Out:
# 258

# %%
result_test = extract_keypoints(results)
len(result_test)
# Out:
# 258

# %%
np.save('testing_version3training', result_test)

# %% [markdown]
# # 4. Setup Folders for Collection of Keypoints for training LSTM model

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['no', 'please', 'thanks', 'welcome', 'yes', 'noaction'])

# 60 videos worth of data
no_sequences = 60

# Videos are going to be 30 frames in length if picture sequence_length = 1
sequence_length = 30

# %%
#create 1 folder for 1 action

for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
                # print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
#Capture Video using webcam
cap = cv2.VideoCapture(0)
# Set mediapipe model 
count = 0
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences): #range(30,60) # 30....59
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):
                
                # Read feed
                ret, frame = cap.read()
                
                # Make detections
                image, results = mediapipe_detection(frame, holistic)
                
                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic # Implement Collection Breaks between each sequence to allow me to reset and reposition to collect the action from start to finish
                if frame_num == 0: #If frame is 0, take a break
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000) #wait for 0.5 seconds
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))

                # save keypoints to folder
                np.save(npy_path, keypoints)
                cv2.imwrite(f'test/{count}.jpg', image)
                count+=1
                
                
                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
import pandas as pd

# %%
#Define Path to training data of numpy arrays
#DATA_PATH = os.path.join('MP_Data_bp_hp')
#DATA_PATH = os.path.join('MP_Data-6classes') # including facemesh
#"C:\Users\yasmi\Desktop\sign-nificant\MP_Data"
DATA_PATH = os.path.join('MP_Data') # including facemesh

# Define Model Run
run = 'run'

#Define directory to save training graphs and confusion matrices
img_dir = f'Logs/{run}/images'

# create directory if image directory does not exist
if not os.path.exists(img_dir):
    os.makedirs(img_dir)    

# Define actions that we try to detect
actions = np.array(['no', 'please', 'thanks', 'welcome', 'yes', 'noaction'])

# Sixty videos worth of data for each action
no_sequences = 60
# Videos are going to be 30 frames in length (30 frames of data for each action)
sequence_length = 30

#create label map dictionary
label_map = {label:num for num, label in enumerate(actions)} 
print(label_map)

#sequences represent x data, labels represent y data/the action classes.
sequences, labels = [], []
#Loop through the action classes you want to detect
for action in actions:
    #loop through each sequence
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# X = Training Data that contains spatial coordinates x,y,z of landmarks
X = np.array(sequences)

# y = categorical labels
y = to_categorical(labels).astype(int) #one-hot-encoding to catergorical variable

print('X Shape:',X.shape)
print('y Shape:',y.shape)

# train test split (80% train,20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,stratify=y)

print('X_train Shape:',X_train.shape)
print('y_train Shape:',y_train.shape)
print('X_test Shape:',X_test.shape)
print('y_test Shape:',y_test.shape)

# split imbalanced dataset into train and test sets with stratification
test_count_label = tf.reduce_sum(y_test, axis=0)
train_count_label = tf.reduce_sum(y_train, axis=0)
# Out:
# {'no': 0, 'please': 1, 'thanks': 2, 'welcome': 3, 'yes': 4, 'noaction': 5}
# X Shape: (360, 30, 258)
# y Shape: (360, 6)
# X_train Shape: (288, 30, 258)
# y_train Shape: (288, 6)
# X_test Shape: (72, 30, 258)
# y_test Shape: (72, 6)

# %%
# Show categorical list
actions.tolist()
# Out:
# ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']

# %%
left = pd.DataFrame(train_count_label,columns=['train_count'])
right = pd.DataFrame(test_count_label,columns=['test_count'])
df = left.join(right)

actions_list = actions.tolist()

left = pd.DataFrame(actions_list,columns=['class_names'])
df = left.join(df)
df
# Out:
#   class_names  train_count  test_count
# 0          no           48          12
# 1      please           48          12
# 2      thanks           48          12
# 3     welcome           48          12
# 4         yes           48          12
# 5    noaction           48          12

# %%
left = pd.DataFrame(train_count_label,columns=['train_count'])
right = pd.DataFrame(test_count_label,columns=['test_count'])
df = left.join(right)

actions_list = actions.tolist()

left = pd.DataFrame(actions_list,columns=['class_names'])
df = left.join(df)
df
# Out:
#   class_names  train_count  test_count
# 0          no           48          12
# 1      please           48          12
# 2      thanks           48          12
# 3     welcome           48          12
# 4         yes           48          12
# 5    noaction           48          12

# %%
# Plot Distribution of Train & Test Data after train_test_split
ax = df.plot.bar(x='class_names',rot=0)
ax.set_title('Distribution of Train & Test Data after train_test_split')
ax.figure.savefig('Logs/images/train_test_distribution.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [45], in <cell line: 4>()
#       2 ax = df.plot.bar(x='class_names',rot=0)
#       3 ax.set_title('Distribution of Train & Test Data after train_test_split')
# ----> 4 ax.figure.savefig('Logs/images/train_test_distribution.jpg')
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:583, in FigureCanvasAgg.print_jpg(self, filename_or_obj, pil_kwargs, *args, **kwargs)
#     581 pil_kwargs.setdefault("dpi", (self.figure.dpi, self.figure.dpi))
#     582 # Drop alpha channel now.
# --> 583 return (Image.fromarray(np.asarray(self.buffer_rgba())[..., :3])
#     584         .save(filename_or_obj, format='jpeg', **pil_kwargs))
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:2209, in Image.save(self, fp, format, **params)
#    2207         fp = builtins.open(filename, "r+b")
#    2208     else:
# -> 2209         fp = builtins.open(filename, "w+b")
#    2211 try:
#    2212     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Logs/images/train_test_distribution.jpg'

# %% [markdown]
# # 7. Training LSTM Model

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard,EarlyStopping

#Set up log directory to monitor training accuracy while training
log_dir = os.path.join('Logs/{}'.format(run))
tb_callback = TensorBoard(log_dir=log_dir)

model_dir = 'Logs/{}/model'.format(run)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
# Build LSTM Model Architecture Layers using Keras high-level # experiment 8
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,258))) #each video has input shape of 30 frames of 1662 keypoints: X.shape
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=False, activation='relu')) #next layer is a dense layer so we do not return sequences here
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
#Compile defines the loss function, the optimizer and the metrics. 
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            82688
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 237,350
# Trainable params: 237,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 800
#checkpoint_dir = f"Logs/{run}/tmp/checkpoint"
model_filename = "Epoch-{epoch:02d}-Loss-{val_loss:.2f}.h5"
checkpoint_filepath = os.path.join('model/',model_filename)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'Logs/{run}/'+checkpoint_filepath,
    monitor='val_loss', #get the minimum validation loss
    mode='min',
    save_weights_only=True,
    save_best_only=True,
    verbose=2)

# Reference: https://towardsdatascience.com/a-practical-introduction-to-early-stopping-in-machine-learning-550ac88bc8fd
early_stopping =EarlyStopping(monitor='val_loss', patience=20,mode='auto',verbose=2)

# %%
#DO NOT RUN IF DONT WANT TO TRAIN
# Reference: https://www.tensorflow.org/guide/keras/train_and_evaluate
print(f"Fit model on training data for {epochs} epochs")
history = model.fit(
    X_train, y_train, 
    #batch_size=64,
    epochs=epochs,
    # We pass some validation data for monitoring validation loss and metrics at the end of each epoch
    validation_data=(X_test, y_test),
    verbose=2,
    batch_size=32,
    callbacks=[tb_callback, model_checkpoint_callback, early_stopping]
)

#https://stats.stackexchange.com/questions/153531/what-is-batch-size-in-neural-network
# Out:
# Fit model on training data for 800 epochs
# Epoch 1/800
#
# Epoch 1: val_loss improved from inf to 0.15701, saving model to Logs/run_version2training/model3\Epoch-01-Loss-0.16.h5
# 9/9 - 0s - loss: 0.1579 - categorical_accuracy: 0.9479 - val_loss: 0.1570 - val_categorical_accuracy: 0.9444 - 379ms/epoch - 42ms/step
# Epoch 2/800
#
# Epoch 2: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.1235 - categorical_accuracy: 0.9618 - val_loss: 0.2792 - val_categorical_accuracy: 0.8889 - 319ms/epoch - 35ms/step
# Epoch 3/800
#
# Epoch 3: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.0992 - categorical_accuracy: 0.9618 - val_loss: 0.1621 - val_categorical_accuracy: 0.9167 - 337ms/epoch - 37ms/step
# Epoch 4/800
#
# Epoch 4: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.0603 - categorical_accuracy: 0.9757 - val_loss: 0.1634 - val_categorical_accuracy: 0.9167 - 321ms/epoch - 36ms/step
# Epoch 5/800
#
# Epoch 5: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.0529 - categorical_accuracy: 0.9792 - val_loss: 0.1850 - val_categorical_accuracy: 0.9167 - 327ms/epoch - 36ms/step
# Epoch 6/800
#
# Epoch 6: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.0683 - categorical_accuracy: 0.9861 - val_loss: 0.3395 - val_categorical_accuracy: 0.8889 - 307ms/epoch - 34ms/step
# Epoch 7/800
#
# Epoch 7: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.1011 - categorical_accuracy: 0.9757 - val_loss: 0.2245 - val_categorical_accuracy: 0.9167 - 318ms/epoch - 35ms/step
# Epoch 8/800
#
# Epoch 8: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.1145 - categorical_accuracy: 0.9653 - val_loss: 0.2882 - val_categorical_accuracy: 0.8750 - 349ms/epoch - 39ms/step
# Epoch 9/800
#
# Epoch 9: val_loss did not improve from 0.15701
# 9/9 - 0s - loss: 0.0739 - categorical_accuracy: 0.9757 - val_loss: 0.2432 - val_categorical_accuracy: 0.9028 - 332ms/epoch - 37ms/step
# Epoch 10/800
#
# Epoch 10: val_loss improved from 0.15701 to 0.12960, saving model to Logs/run_version2training/model3\Epoch-10-Loss-0.13.h5
# 9/9 - 0s - loss: 0.0671 - categorical_accuracy: 0.9792 - val_loss: 0.1296 - val_categorical_accuracy: 0.9444 - 333ms/epoch - 37ms/step
# Epoch 11/800
#
# Epoch 11: val_loss did not improve from 0.12960
# 9/9 - 0s - loss: 0.0387 - categorical_accuracy: 0.9931 - val_loss: 0.1408 - val_categorical_accuracy: 0.9444 - 337ms/epoch - 37ms/step
# Epoch 12/800
#
# Epoch 12: val_loss did not improve from 0.12960
# 9/9 - 0s - loss: 0.0288 - categorical_accuracy: 0.9931 - val_loss: 0.2137 - val_categorical_accuracy: 0.9306 - 335ms/epoch - 37ms/step
# Epoch 13/800
#
# Epoch 13: val_loss improved from 0.12960 to 0.12687, saving model to Logs/run_version2training/model3\Epoch-13-Loss-0.13.h5
# 9/9 - 0s - loss: 0.0540 - categorical_accuracy: 0.9826 - val_loss: 0.1269 - val_categorical_accuracy: 0.9444 - 363ms/epoch - 40ms/step
# Epoch 14/800
#
# Epoch 14: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0293 - categorical_accuracy: 0.9931 - val_loss: 0.2455 - val_categorical_accuracy: 0.9028 - 335ms/epoch - 37ms/step
# Epoch 15/800
#
# Epoch 15: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0301 - categorical_accuracy: 0.9826 - val_loss: 0.1858 - val_categorical_accuracy: 0.9167 - 320ms/epoch - 36ms/step
# Epoch 16/800
#
# Epoch 16: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0301 - categorical_accuracy: 0.9861 - val_loss: 0.1947 - val_categorical_accuracy: 0.9167 - 339ms/epoch - 38ms/step
# Epoch 17/800
#
# Epoch 17: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0401 - categorical_accuracy: 0.9861 - val_loss: 0.5541 - val_categorical_accuracy: 0.9028 - 321ms/epoch - 36ms/step
# Epoch 18/800
#
# Epoch 18: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0881 - categorical_accuracy: 0.9757 - val_loss: 0.3124 - val_categorical_accuracy: 0.9028 - 341ms/epoch - 38ms/step
# Epoch 19/800
#
# Epoch 19: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0520 - categorical_accuracy: 0.9826 - val_loss: 0.2378 - val_categorical_accuracy: 0.9028 - 342ms/epoch - 38ms/step
# Epoch 20/800
#
# Epoch 20: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0405 - categorical_accuracy: 0.9861 - val_loss: 0.2331 - val_categorical_accuracy: 0.9444 - 340ms/epoch - 38ms/step
# Epoch 21/800
#
# Epoch 21: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0284 - categorical_accuracy: 0.9931 - val_loss: 0.1545 - val_categorical_accuracy: 0.9306 - 316ms/epoch - 35ms/step
# Epoch 22/800
#
# Epoch 22: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0478 - categorical_accuracy: 0.9861 - val_loss: 0.1322 - val_categorical_accuracy: 0.9444 - 317ms/epoch - 35ms/step
# Epoch 23/800
#
# Epoch 23: val_loss did not improve from 0.12687
# 9/9 - 0s - loss: 0.0593 - categorical_accuracy: 0.9722 - val_loss: 0.3000 - val_categorical_accuracy: 0.8889 - 324ms/epoch - 36ms/step
# Epoch 24/800
#
# Epoch 24: val_loss improved from 0.12687 to 0.11704, saving model to Logs/run_version2training/model3\Epoch-24-Loss-0.12.h5
# 9/9 - 0s - loss: 0.0606 - categorical_accuracy: 0.9722 - val_loss: 0.1170 - val_categorical_accuracy: 0.9722 - 344ms/epoch - 38ms/step
# Epoch 25/800
#
# Epoch 25: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0344 - categorical_accuracy: 0.9896 - val_loss: 0.2443 - val_categorical_accuracy: 0.9167 - 343ms/epoch - 38ms/step
# Epoch 26/800
#
# Epoch 26: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0226 - categorical_accuracy: 0.9931 - val_loss: 0.1650 - val_categorical_accuracy: 0.9167 - 340ms/epoch - 38ms/step
# Epoch 27/800
#
# Epoch 27: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0172 - categorical_accuracy: 0.9965 - val_loss: 0.1569 - val_categorical_accuracy: 0.9583 - 367ms/epoch - 41ms/step
# Epoch 28/800
#
# Epoch 28: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0228 - categorical_accuracy: 0.9896 - val_loss: 0.3014 - val_categorical_accuracy: 0.9167 - 353ms/epoch - 39ms/step
# Epoch 29/800
#
# Epoch 29: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0189 - categorical_accuracy: 0.9965 - val_loss: 0.1814 - val_categorical_accuracy: 0.9444 - 377ms/epoch - 42ms/step
# Epoch 30/800
#
# Epoch 30: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0047 - categorical_accuracy: 1.0000 - val_loss: 0.2120 - val_categorical_accuracy: 0.9444 - 378ms/epoch - 42ms/step
# Epoch 31/800
#
# Epoch 31: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0169 - categorical_accuracy: 0.9931 - val_loss: 0.2320 - val_categorical_accuracy: 0.9444 - 388ms/epoch - 43ms/step
# Epoch 32/800
#
# Epoch 32: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0407 - categorical_accuracy: 0.9861 - val_loss: 0.3062 - val_categorical_accuracy: 0.9167 - 369ms/epoch - 41ms/step
# Epoch 33/800
#
# Epoch 33: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0118 - categorical_accuracy: 0.9965 - val_loss: 0.2378 - val_categorical_accuracy: 0.9444 - 352ms/epoch - 39ms/step
# Epoch 34/800
#
# Epoch 34: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0113 - categorical_accuracy: 0.9931 - val_loss: 0.2082 - val_categorical_accuracy: 0.9306 - 337ms/epoch - 37ms/step
# Epoch 35/800
#
# Epoch 35: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0071 - categorical_accuracy: 0.9965 - val_loss: 0.1880 - val_categorical_accuracy: 0.9444 - 334ms/epoch - 37ms/step
# Epoch 36/800
#
# Epoch 36: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0067 - categorical_accuracy: 0.9965 - val_loss: 0.2450 - val_categorical_accuracy: 0.9306 - 320ms/epoch - 36ms/step
# Epoch 37/800
#
# Epoch 37: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0071 - categorical_accuracy: 0.9965 - val_loss: 0.2396 - val_categorical_accuracy: 0.9444 - 332ms/epoch - 37ms/step
# Epoch 38/800
#
# Epoch 38: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0081 - categorical_accuracy: 0.9965 - val_loss: 0.1858 - val_categorical_accuracy: 0.9444 - 320ms/epoch - 36ms/step
# Epoch 39/800
#
# Epoch 39: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0176 - categorical_accuracy: 0.9965 - val_loss: 0.2229 - val_categorical_accuracy: 0.9306 - 323ms/epoch - 36ms/step
# Epoch 40/800
#
# Epoch 40: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0068 - categorical_accuracy: 0.9965 - val_loss: 0.1576 - val_categorical_accuracy: 0.9444 - 330ms/epoch - 37ms/step
# Epoch 41/800
#
# Epoch 41: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0178 - categorical_accuracy: 0.9931 - val_loss: 0.2668 - val_categorical_accuracy: 0.9306 - 317ms/epoch - 35ms/step
# Epoch 42/800
#
# Epoch 42: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0291 - categorical_accuracy: 0.9861 - val_loss: 0.2940 - val_categorical_accuracy: 0.9306 - 316ms/epoch - 35ms/step
# Epoch 43/800
#
# Epoch 43: val_loss did not improve from 0.11704
# 9/9 - 0s - loss: 0.0246 - categorical_accuracy: 0.9965 - val_loss: 0.2595 - val_categorical_accuracy: 0.8750 - 332ms/epoch - 37ms/step
# Epoch 44/800
#
# Epoch 44: val_loss improved from 0.11704 to 0.10698, saving model to Logs/run_version2training/model3\Epoch-44-Loss-0.11.h5
# 9/9 - 0s - loss: 0.0355 - categorical_accuracy: 0.9896 - val_loss: 0.1070 - val_categorical_accuracy: 0.9722 - 351ms/epoch - 39ms/step
# Epoch 45/800
#
# Epoch 45: val_loss did not improve from 0.10698
# 9/9 - 0s - loss: 0.0135 - categorical_accuracy: 0.9965 - val_loss: 0.1849 - val_categorical_accuracy: 0.9167 - 339ms/epoch - 38ms/step
# Epoch 46/800
#
# Epoch 46: val_loss did not improve from 0.10698
# 9/9 - 0s - loss: 0.0228 - categorical_accuracy: 0.9896 - val_loss: 0.1310 - val_categorical_accuracy: 0.9583 - 326ms/epoch - 36ms/step
# Epoch 47/800
#
# Epoch 47: val_loss did not improve from 0.10698
# 9/9 - 0s - loss: 0.0655 - categorical_accuracy: 0.9688 - val_loss: 0.1671 - val_categorical_accuracy: 0.9306 - 320ms/epoch - 36ms/step
# Epoch 48/800
#
# Epoch 48: val_loss did not improve from 0.10698
# 9/9 - 0s - loss: 0.0323 - categorical_accuracy: 0.9861 - val_loss: 0.1141 - val_categorical_accuracy: 0.9583 - 344ms/epoch - 38ms/step
# Epoch 49/800
#
# Epoch 49: val_loss did not improve from 0.10698
# 9/9 - 0s - loss: 0.0391 - categorical_accuracy: 0.9861 - val_loss: 0.1140 - val_categorical_accuracy: 0.9444 - 323ms/epoch - 36ms/step
# Epoch 50/800
#
# Epoch 50: val_loss improved from 0.10698 to 0.09075, saving model to Logs/run_version2training/model3\Epoch-50-Loss-0.09.h5
# 9/9 - 0s - loss: 0.0158 - categorical_accuracy: 0.9965 - val_loss: 0.0908 - val_categorical_accuracy: 0.9583 - 324ms/epoch - 36ms/step
# Epoch 51/800
#
# Epoch 51: val_loss improved from 0.09075 to 0.09073, saving model to Logs/run_version2training/model3\Epoch-51-Loss-0.09.h5
# 9/9 - 0s - loss: 0.0106 - categorical_accuracy: 0.9965 - val_loss: 0.0907 - val_categorical_accuracy: 0.9722 - 343ms/epoch - 38ms/step
# Epoch 52/800
#
# Epoch 52: val_loss did not improve from 0.09073
# 9/9 - 0s - loss: 0.0277 - categorical_accuracy: 0.9896 - val_loss: 0.1378 - val_categorical_accuracy: 0.9306 - 335ms/epoch - 37ms/step
# Epoch 53/800
#
# Epoch 53: val_loss improved from 0.09073 to 0.08408, saving model to Logs/run_version2training/model3\Epoch-53-Loss-0.08.h5
# 9/9 - 0s - loss: 0.0144 - categorical_accuracy: 0.9965 - val_loss: 0.0841 - val_categorical_accuracy: 0.9583 - 344ms/epoch - 38ms/step
# Epoch 54/800
#
# Epoch 54: val_loss did not improve from 0.08408
# 9/9 - 0s - loss: 0.0202 - categorical_accuracy: 0.9931 - val_loss: 0.2560 - val_categorical_accuracy: 0.8750 - 327ms/epoch - 36ms/step
# Epoch 55/800
#
# Epoch 55: val_loss did not improve from 0.08408
# 9/9 - 0s - loss: 0.0630 - categorical_accuracy: 0.9826 - val_loss: 0.1210 - val_categorical_accuracy: 0.9444 - 318ms/epoch - 35ms/step
# Epoch 56/800
#
# Epoch 56: val_loss did not improve from 0.08408
# 9/9 - 0s - loss: 0.1078 - categorical_accuracy: 0.9618 - val_loss: 0.2812 - val_categorical_accuracy: 0.9167 - 321ms/epoch - 36ms/step
# Epoch 57/800
#
# Epoch 57: val_loss did not improve from 0.08408
# 9/9 - 0s - loss: 0.0539 - categorical_accuracy: 0.9792 - val_loss: 0.1166 - val_categorical_accuracy: 0.9583 - 323ms/epoch - 36ms/step
# Epoch 58/800
#
# Epoch 58: val_loss did not improve from 0.08408
# 9/9 - 0s - loss: 0.0956 - categorical_accuracy: 0.9688 - val_loss: 0.2391 - val_categorical_accuracy: 0.9167 - 326ms/epoch - 36ms/step
# Epoch 59/800
#
# Epoch 59: val_loss did not improve from 0.08408
# 9/9 - 0s - loss: 0.0448 - categorical_accuracy: 0.9896 - val_loss: 0.1308 - val_categorical_accuracy: 0.9306 - 310ms/epoch - 34ms/step
# Epoch 60/800
#
# Epoch 60: val_loss improved from 0.08408 to 0.07334, saving model to Logs/run_version2training/model3\Epoch-60-Loss-0.07.h5
# 9/9 - 0s - loss: 0.0516 - categorical_accuracy: 0.9792 - val_loss: 0.0733 - val_categorical_accuracy: 0.9583 - 348ms/epoch - 39ms/step
# Epoch 61/800
#
# Epoch 61: val_loss did not improve from 0.07334
# 9/9 - 0s - loss: 0.0377 - categorical_accuracy: 0.9896 - val_loss: 0.1962 - val_categorical_accuracy: 0.9167 - 339ms/epoch - 38ms/step
# Epoch 62/800
#
# Epoch 62: val_loss improved from 0.07334 to 0.05278, saving model to Logs/run_version2training/model3\Epoch-62-Loss-0.05.h5
# 9/9 - 0s - loss: 0.0302 - categorical_accuracy: 0.9861 - val_loss: 0.0528 - val_categorical_accuracy: 0.9583 - 328ms/epoch - 36ms/step
# Epoch 63/800
#
# Epoch 63: val_loss did not improve from 0.05278
# 9/9 - 0s - loss: 0.0152 - categorical_accuracy: 0.9931 - val_loss: 0.1167 - val_categorical_accuracy: 0.9444 - 309ms/epoch - 34ms/step
# Epoch 64/800
#
# Epoch 64: val_loss improved from 0.05278 to 0.05076, saving model to Logs/run_version2training/model3\Epoch-64-Loss-0.05.h5
# 9/9 - 0s - loss: 0.0088 - categorical_accuracy: 0.9965 - val_loss: 0.0508 - val_categorical_accuracy: 0.9861 - 338ms/epoch - 38ms/step
# Epoch 65/800
#
# Epoch 65: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0057 - categorical_accuracy: 1.0000 - val_loss: 0.0572 - val_categorical_accuracy: 0.9861 - 322ms/epoch - 36ms/step
# Epoch 66/800
#
# Epoch 66: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.1165 - val_categorical_accuracy: 0.9583 - 324ms/epoch - 36ms/step
# Epoch 67/800
#
# Epoch 67: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0062 - categorical_accuracy: 0.9965 - val_loss: 0.0680 - val_categorical_accuracy: 0.9722 - 327ms/epoch - 36ms/step
# Epoch 68/800
#
# Epoch 68: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 0.0809 - val_categorical_accuracy: 0.9722 - 322ms/epoch - 36ms/step
# Epoch 69/800
#
# Epoch 69: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.0938 - val_categorical_accuracy: 0.9722 - 336ms/epoch - 37ms/step
# Epoch 70/800
#
# Epoch 70: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.0750 - val_categorical_accuracy: 0.9722 - 338ms/epoch - 38ms/step
# Epoch 71/800
#
# Epoch 71: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0032 - categorical_accuracy: 1.0000 - val_loss: 0.0905 - val_categorical_accuracy: 0.9722 - 334ms/epoch - 37ms/step
# Epoch 72/800
#
# Epoch 72: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 8.5049e-04 - categorical_accuracy: 1.0000 - val_loss: 0.1190 - val_categorical_accuracy: 0.9583 - 336ms/epoch - 37ms/step
# Epoch 73/800
#
# Epoch 73: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 9.9741e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0978 - val_categorical_accuracy: 0.9722 - 331ms/epoch - 37ms/step
# Epoch 74/800
#
# Epoch 74: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 5.2111e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0894 - val_categorical_accuracy: 0.9861 - 338ms/epoch - 38ms/step
# Epoch 75/800
#
# Epoch 75: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 6.5337e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0906 - val_categorical_accuracy: 0.9861 - 324ms/epoch - 36ms/step
# Epoch 76/800
#
# Epoch 76: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 9.6884e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0916 - val_categorical_accuracy: 0.9861 - 340ms/epoch - 38ms/step
# Epoch 77/800
#
# Epoch 77: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 5.8036e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0861 - val_categorical_accuracy: 0.9861 - 357ms/epoch - 40ms/step
# Epoch 78/800
#
# Epoch 78: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 4.6947e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0817 - val_categorical_accuracy: 0.9861 - 341ms/epoch - 38ms/step
# Epoch 79/800
#
# Epoch 79: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0049 - categorical_accuracy: 0.9965 - val_loss: 0.1040 - val_categorical_accuracy: 0.9722 - 322ms/epoch - 36ms/step
# Epoch 80/800
#
# Epoch 80: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0099 - categorical_accuracy: 0.9965 - val_loss: 0.2430 - val_categorical_accuracy: 0.9306 - 328ms/epoch - 36ms/step
# Epoch 81/800
#
# Epoch 81: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.0903 - categorical_accuracy: 0.9757 - val_loss: 0.1923 - val_categorical_accuracy: 0.9444 - 315ms/epoch - 35ms/step
# Epoch 82/800
#
# Epoch 82: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.1033 - categorical_accuracy: 0.9618 - val_loss: 0.0946 - val_categorical_accuracy: 0.9722 - 329ms/epoch - 37ms/step
# Epoch 83/800
#
# Epoch 83: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 0.1602 - categorical_accuracy: 0.9514 - val_loss: 0.5891 - val_categorical_accuracy: 0.8194 - 320ms/epoch - 36ms/step
# Epoch 84/800
#
# Epoch 84: val_loss did not improve from 0.05076
# 9/9 - 0s - loss: 1.1444 - categorical_accuracy: 0.7465 - val_loss: 2.9082 - val_categorical_accuracy: 0.4583 - 327ms/epoch - 36ms/step
# Epoch 84: early stopping

# %% [markdown]
# # 8. Plot Training Results

# %%
import pandas as pd
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

hist_df.to_csv(f'./Logs/{run}/history.csv',index = False)

df_hist = pd.read_csv(f'./Logs/{run}/history.csv')
hist_df
# Out:
#         loss  categorical_accuracy  val_loss  val_categorical_accuracy
# 0   0.157865              0.947917  0.157007                  0.944444
# 1   0.123470              0.961806  0.279166                  0.888889
# 2   0.099240              0.961806  0.162105                  0.916667
# 3   0.060295              0.975694  0.163434                  0.916667
# 4   0.052938              0.979167  0.185035                  0.916667
# ..       ...                   ...       ...                       ...
# 79  0.009879              0.996528  0.243044                  0.930556
# 80  0.090345              0.975694  0.192253                  0.944444
# 81  0.103333              0.961806  0.094640                  0.972222
# 82  0.160156              0.951389  0.589100                  0.819444
# 83  1.144361              0.746528  2.908229                  0.458333
#
# [84 rows x 4 columns]

# %%
min_loss_epoch = hist_df[hist_df['loss']==min(hist_df['loss'])].index.values
min_loss = min(hist_df['loss'])
print('Index of Minimum Loss =',min_loss_epoch[0])
print('Minimum Loss =',round(min_loss,2))
# Out:
# Index of Minimum Loss = 77
# Minimum Loss = 0.0

# %%
# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Training and Validation Categorical Accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig(f'{img_dir}/Model Training and Validation Categorical Accuracy.jpg')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Training and Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig(f'{img_dir}/Model Training and Validation Loss.jpg')
plt.show()

# %% [markdown]
# # 10. Load Best Model Weights/Checkpoint

# %%
#PATH: "C:\Users\yasmi\Desktop\data science\Logs\run_version2training\model\Epoch-72-Loss-0.15.h5"
#"C:\Users\yasmi\Desktop\sign-nificant\notebook\Logs\run\model\Epoch-64-Loss-0.05.h5"
model.load_weights('C:/Users/yasmi/Desktop/sign-nificant/notebook/Logs/run/model/Epoch-64-Loss-0.05.h5')

# %% [markdown]
# # 11. Make Predictions on X_test

# %%
res = model.predict(X_test)

# Get y_predict and apply softmax function
np.argmax(res[6])
# Out:
# 3/3 [==============================] - 1s 16ms/step
# 2

# %%
# Predicted Action
actions[np.argmax(res[4])]
# Out:
# 'please'

# %%
# Actual Action
actions[np.argmax(y_test[4])]
# Out:
# 'please'

# %% [markdown]
# # 12. Model Evaluation (Categorical Accuracy and Confusion Matrix)
# Running these cells converts the predicition from their one-hot encoded representation to a categorical label e.g. 0,1 or 2 as opoosed to [1,0,0], [0,1,0] or [0,0,1].

# %%
X_test.shape
# Out:
# (72, 30, 258)

# %%
label_list = ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']
label_list
# Out:
# ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']

# %%
label_list = list(label_map.keys())
label_list
# Out:
# ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

def generate_confusion_matrix_accuracy(X,y,types):
    predictions = model.predict(X)
    y_true = np.argmax(y, axis=1)
    y_pred = np.argmax(predictions, axis=1)
    cm = confusion_matrix(y_true, y_pred)

    print(f'{types} Overall Multiclassification Accuracy Score across all classes:',round(accuracy_score(y_true, y_pred),2))

    sns.heatmap(cm, xticklabels = label_list, yticklabels = label_list, annot = True, linewidths = 0.1, fmt='d',cmap='Blues') # cmap = 'YlGnBu')
    plt.title(f"{types} Confusion matrix", fontsize = 15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
generate_confusion_matrix_accuracy(X_train,y_train,'Train')
# Out:
# 9/9 [==============================] - 0s 21ms/step
# Train Overall Multiclassification Accuracy Score across all classes: 1.0

# %%
generate_confusion_matrix_accuracy(X_test,y_test,'Test')
# Out:
# 3/3 [==============================] - 0s 19ms/step
# Test Overall Multiclassification Accuracy Score across all classes: 1.0

# %%
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# predict on test data
y_pred = model.predict(X_test)

# convert predictions to binary labels
y_pred = (y_pred > 0.5)

# calculate precision, recall, f1-score, and accuracy
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("Precision: ", precision)
print("Recall: ", recall)
print("F1-Score: ", f1_score)
print("Accuracy: ", accuracy)
# Out:
# 3/3 [==============================] - 0s 16ms/step
# Precision:  [1. 1. 1. 1. 1. 1.]
# Recall:  [1. 1. 1. 1. 1. 1.]
# F1-Score:  [1. 1. 1. 1. 1. 1.]
# Accuracy:  1.0

# %% [markdown]
# # 13. Run Real Time Keypoint Detection Model Using Webcam

# %%
colors = [(245,221,173), (245,185,265), (146,235,193),(204,152,295),(255,217,179),(0,0,179)]

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables

#collect 30 frames
sequence = []

#concantenate 
sentence = []

#confident matrix
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
