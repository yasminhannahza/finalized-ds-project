# %% [markdown]
# # 1. Preprocess Data and Create Labels and Features

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
import pandas as pd

# %%
#Define Path to training data of numpy arrays
#DATA_PATH = os.path.join('MP_Data_bp_hp')
#DATA_PATH = os.path.join('MP_Data-6classes') # including facemesh

DATA_PATH = os.path.join('MP_Data') # including facemesh

# Define Model Run
run = 'run'

#Define directory to save training graphs and confusion matrices
img_dir = f'Logs/{run}/images'

# create directory if image directory does not exist
if not os.path.exists(img_dir):
    os.makedirs(img_dir)    

# Define actions that we try to detect
actions = np.array(['no', 'please', 'thanks', 'welcome', 'yes', 'noaction'])

# Sixty videos worth of data for each action
no_sequences = 60
# Videos are going to be 30 frames in length (30 frames of data for each action)
sequence_length = 30

#create label map dictionary
label_map = {label:num for num, label in enumerate(actions)} 
print(label_map)

#sequences represent x data, labels represent y data/the action classes.
sequences, labels = [], []
#Loop through the action classes you want to detect
for action in actions:
    #loop through each sequence
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# X = Training Data that contains spatial coordinates x,y,z of landmarks
X = np.array(sequences)

# y = categorical labels
y = to_categorical(labels).astype(int) #one-hot-encoding to catergorical variable

print('X Shape:',X.shape)
print('y Shape:',y.shape)

# train test split (95% train,5% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,stratify=y)

print('X_train Shape:',X_train.shape)
print('y_train Shape:',y_train.shape)
print('X_test Shape:',X_test.shape)
print('y_test Shape:',y_test.shape)

# split imbalanced dataset into train and test sets with stratification
test_count_label = tf.reduce_sum(y_test, axis=0)
train_count_label = tf.reduce_sum(y_train, axis=0)
# Out:
# {'no': 0, 'please': 1, 'thanks': 2, 'welcome': 3, 'yes': 4, 'noaction': 5}

# %%
# Show categorical list
actions.tolist()

# %%
left = pd.DataFrame(train_count_label,columns=['train_count'])
right = pd.DataFrame(test_count_label,columns=['test_count'])
df = left.join(right)

actions_list = actions.tolist()

left = pd.DataFrame(actions_list,columns=['class_names'])
df = left.join(df)
df

# %%
left = pd.DataFrame(train_count_label,columns=['train_count'])
right = pd.DataFrame(test_count_label,columns=['test_count'])
df = left.join(right)

actions_list = actions.tolist()

left = pd.DataFrame(actions_list,columns=['class_names'])
df = left.join(df)
df

# %%
# Plot Distribution of Train & Test Data after train_test_split
ax = df.plot.bar(x='class_names',rot=0)
ax.set_title('Distribution of Train & Test Data after train_test_split')
ax.figure.savefig('Logs/run/images/train_test_distribution.jpg')

# %% [markdown]
# # 2. Training LSTM Model

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard,EarlyStopping

#Set up log directory to monitor training accuracy while training
log_dir = os.path.join('Logs/{}'.format(run))
tb_callback = TensorBoard(log_dir=log_dir)

model_dir = 'Logs/{}/model_LSTM'.format(run)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
# Build LSTM Model Architecture Layers using Keras high-level # experiment 8
modelLSTM = Sequential()
modelLSTM.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,258))) #each video has input shape of 30 frames of 1662 keypoints: X.shape
modelLSTM.add(Dropout(0.2))
modelLSTM.add(LSTM(128, return_sequences=True, activation='relu'))
modelLSTM.add(Dropout(0.2))
modelLSTM.add(LSTM(64, return_sequences=False, activation='relu')) #next layer is a dense layer so we do not return sequences here
modelLSTM.add(Dense(64, activation='relu'))
modelLSTM.add(Dense(32, activation='relu'))
modelLSTM.add(Dense(actions.shape[0], activation='softmax'))

# %%
#Compile defines the loss function, the optimizer and the metrics. 
modelLSTM.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
modelLSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            82688
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 237,350
# Trainable params: 237,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 800
#checkpoint_dir = f"Logs/{run}/tmp/checkpoint"
model_filename = "Epoch-{epoch:02d}-Loss-{val_loss:.2f}.h5"
checkpoint_filepath = os.path.join('model_LSTM/',model_filename)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'Logs/{run}/'+checkpoint_filepath,
    monitor='val_loss', #get the minimum validation loss
    mode='min',
    save_weights_only=True,
    save_best_only=True,
    verbose=2)

# Reference: https://towardsdatascience.com/a-practical-introduction-to-early-stopping-in-machine-learning-550ac88bc8fd
early_stopping =EarlyStopping(monitor='val_loss', patience=20,mode='auto',verbose=2)

# %%
#DO NOT RUN IF DONT WANT TO TRAIN
# Reference: https://www.tensorflow.org/guide/keras/train_and_evaluate
print(f"Fit model on training data for {epochs} epochs")
history_LSTM = modelLSTM.fit(
    X_train, y_train, 
    #batch_size=64,
    epochs=epochs,
    # We pass some validation data for monitoring validation loss and metrics at the end of each epoch
    validation_data=(X_test, y_test),
    verbose=2,
    batch_size=32,
    callbacks=[tb_callback, model_checkpoint_callback, early_stopping]
)

#https://stats.stackexchange.com/questions/153531/what-is-batch-size-in-neural-network
# Out:
# Fit model on training data for 800 epochs
# Epoch 1/800
#
# Epoch 1: val_loss did not improve from 0.18574
# 9/9 - 0s - loss: 0.0858 - categorical_accuracy: 0.9688 - val_loss: 0.3270 - val_categorical_accuracy: 0.9167 - 340ms/epoch - 38ms/step
# Epoch 2/800
#
# Epoch 2: val_loss did not improve from 0.18574
# 9/9 - 0s - loss: 0.1551 - categorical_accuracy: 0.9479 - val_loss: 0.2743 - val_categorical_accuracy: 0.9167 - 309ms/epoch - 34ms/step
# Epoch 3/800
#
# Epoch 3: val_loss improved from 0.18574 to 0.11283, saving model to Logs/run/model_CNN\Epoch-03-Loss-0.11.h5
# 9/9 - 0s - loss: 0.1392 - categorical_accuracy: 0.9479 - val_loss: 0.1128 - val_categorical_accuracy: 0.9722 - 308ms/epoch - 34ms/step
# Epoch 4/800
#
# Epoch 4: val_loss did not improve from 0.11283
# 9/9 - 0s - loss: 0.1128 - categorical_accuracy: 0.9688 - val_loss: 0.1427 - val_categorical_accuracy: 0.9583 - 314ms/epoch - 35ms/step
# Epoch 5/800
#
# Epoch 5: val_loss did not improve from 0.11283
# 9/9 - 0s - loss: 0.0435 - categorical_accuracy: 0.9931 - val_loss: 0.1756 - val_categorical_accuracy: 0.9444 - 306ms/epoch - 34ms/step
# Epoch 6/800
#
# Epoch 6: val_loss did not improve from 0.11283
# 9/9 - 0s - loss: 0.0672 - categorical_accuracy: 0.9826 - val_loss: 0.1177 - val_categorical_accuracy: 0.9583 - 312ms/epoch - 35ms/step
# Epoch 7/800
#
# Epoch 7: val_loss improved from 0.11283 to 0.09797, saving model to Logs/run/model_CNN\Epoch-07-Loss-0.10.h5
# 9/9 - 0s - loss: 0.0793 - categorical_accuracy: 0.9722 - val_loss: 0.0980 - val_categorical_accuracy: 0.9722 - 317ms/epoch - 35ms/step
# Epoch 8/800
#
# Epoch 8: val_loss did not improve from 0.09797
# 9/9 - 0s - loss: 0.0665 - categorical_accuracy: 0.9792 - val_loss: 0.1586 - val_categorical_accuracy: 0.9583 - 295ms/epoch - 33ms/step
# Epoch 9/800
#
# Epoch 9: val_loss improved from 0.09797 to 0.08647, saving model to Logs/run/model_CNN\Epoch-09-Loss-0.09.h5
# 9/9 - 0s - loss: 0.0335 - categorical_accuracy: 0.9896 - val_loss: 0.0865 - val_categorical_accuracy: 0.9722 - 330ms/epoch - 37ms/step
# Epoch 10/800
#
# Epoch 10: val_loss did not improve from 0.08647
# 9/9 - 0s - loss: 0.0355 - categorical_accuracy: 0.9896 - val_loss: 0.0954 - val_categorical_accuracy: 0.9722 - 322ms/epoch - 36ms/step
# Epoch 11/800
#
# Epoch 11: val_loss did not improve from 0.08647
# 9/9 - 0s - loss: 0.0144 - categorical_accuracy: 1.0000 - val_loss: 0.1217 - val_categorical_accuracy: 0.9722 - 293ms/epoch - 33ms/step
# Epoch 12/800
#
# Epoch 12: val_loss did not improve from 0.08647
# 9/9 - 0s - loss: 0.0111 - categorical_accuracy: 1.0000 - val_loss: 0.0910 - val_categorical_accuracy: 0.9722 - 296ms/epoch - 33ms/step
# Epoch 13/800
#
# Epoch 13: val_loss did not improve from 0.08647
# 9/9 - 0s - loss: 0.0096 - categorical_accuracy: 0.9965 - val_loss: 0.1099 - val_categorical_accuracy: 0.9722 - 323ms/epoch - 36ms/step
# Epoch 14/800
#
# Epoch 14: val_loss did not improve from 0.08647
# 9/9 - 0s - loss: 0.0058 - categorical_accuracy: 1.0000 - val_loss: 0.1518 - val_categorical_accuracy: 0.9583 - 309ms/epoch - 34ms/step
# Epoch 15/800
#
# Epoch 15: val_loss improved from 0.08647 to 0.08459, saving model to Logs/run/model_CNN\Epoch-15-Loss-0.08.h5
# 9/9 - 0s - loss: 0.0066 - categorical_accuracy: 1.0000 - val_loss: 0.0846 - val_categorical_accuracy: 0.9722 - 319ms/epoch - 35ms/step
# Epoch 16/800
#
# Epoch 16: val_loss improved from 0.08459 to 0.07858, saving model to Logs/run/model_CNN\Epoch-16-Loss-0.08.h5
# 9/9 - 0s - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 0.0786 - val_categorical_accuracy: 0.9722 - 320ms/epoch - 36ms/step
# Epoch 17/800
#
# Epoch 17: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0123 - categorical_accuracy: 0.9965 - val_loss: 0.1569 - val_categorical_accuracy: 0.9583 - 296ms/epoch - 33ms/step
# Epoch 18/800
#
# Epoch 18: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0082 - categorical_accuracy: 0.9965 - val_loss: 0.1736 - val_categorical_accuracy: 0.9583 - 308ms/epoch - 34ms/step
# Epoch 19/800
#
# Epoch 19: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0066 - categorical_accuracy: 1.0000 - val_loss: 0.1072 - val_categorical_accuracy: 0.9722 - 297ms/epoch - 33ms/step
# Epoch 20/800
#
# Epoch 20: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0038 - categorical_accuracy: 1.0000 - val_loss: 0.1522 - val_categorical_accuracy: 0.9583 - 318ms/epoch - 35ms/step
# Epoch 21/800
#
# Epoch 21: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0046 - categorical_accuracy: 1.0000 - val_loss: 0.0875 - val_categorical_accuracy: 0.9722 - 321ms/epoch - 36ms/step
# Epoch 22/800
#
# Epoch 22: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.1625 - val_categorical_accuracy: 0.9583 - 322ms/epoch - 36ms/step
# Epoch 23/800
#
# Epoch 23: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.1457 - val_categorical_accuracy: 0.9583 - 310ms/epoch - 34ms/step
# Epoch 24/800
#
# Epoch 24: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.0873 - val_categorical_accuracy: 0.9722 - 310ms/epoch - 34ms/step
# Epoch 25/800
#
# Epoch 25: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 6.9919e-04 - categorical_accuracy: 1.0000 - val_loss: 0.1131 - val_categorical_accuracy: 0.9583 - 317ms/epoch - 35ms/step
# Epoch 26/800
#
# Epoch 26: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.1364 - val_categorical_accuracy: 0.9583 - 308ms/epoch - 34ms/step
# Epoch 27/800
#
# Epoch 27: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 8.6393e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0864 - val_categorical_accuracy: 0.9722 - 350ms/epoch - 39ms/step
# Epoch 28/800
#
# Epoch 28: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.1414 - val_categorical_accuracy: 0.9722 - 320ms/epoch - 36ms/step
# Epoch 29/800
#
# Epoch 29: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.1186 - val_categorical_accuracy: 0.9722 - 305ms/epoch - 34ms/step
# Epoch 30/800
#
# Epoch 30: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 4.3293e-04 - categorical_accuracy: 1.0000 - val_loss: 0.1157 - val_categorical_accuracy: 0.9583 - 313ms/epoch - 35ms/step
# Epoch 31/800
#
# Epoch 31: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 3.9974e-04 - categorical_accuracy: 1.0000 - val_loss: 0.1114 - val_categorical_accuracy: 0.9722 - 312ms/epoch - 35ms/step
# Epoch 32/800
#
# Epoch 32: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.1329 - categorical_accuracy: 0.9688 - val_loss: 1.4565 - val_categorical_accuracy: 0.7222 - 301ms/epoch - 33ms/step
# Epoch 33/800
#
# Epoch 33: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.6681 - categorical_accuracy: 0.7951 - val_loss: 0.6111 - val_categorical_accuracy: 0.7500 - 309ms/epoch - 34ms/step
# Epoch 34/800
#
# Epoch 34: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.6897 - categorical_accuracy: 0.6806 - val_loss: 0.6416 - val_categorical_accuracy: 0.8333 - 313ms/epoch - 35ms/step
# Epoch 35/800
#
# Epoch 35: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.4866 - categorical_accuracy: 0.8299 - val_loss: 0.3799 - val_categorical_accuracy: 0.8889 - 309ms/epoch - 34ms/step
# Epoch 36/800
#
# Epoch 36: val_loss did not improve from 0.07858
# 9/9 - 0s - loss: 0.4082 - categorical_accuracy: 0.8576 - val_loss: 0.3283 - val_categorical_accuracy: 0.9444 - 311ms/epoch - 35ms/step
# Epoch 36: early stopping

# %% [markdown]
# # 3. CNN Model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.optimizers import Adam

#Set up log directory to monitor training accuracy while training
log_dir = os.path.join('Logs/{}'.format(run))
tb_callback = TensorBoard(log_dir=log_dir)

model_dir = 'Logs/{}/model_CNN'.format(run)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
# define the model
modelCNN = Sequential()
modelCNN.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(30, 258, 1)))
modelCNN.add(MaxPooling2D(pool_size=(2,2)))
modelCNN.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
modelCNN.add(MaxPooling2D(pool_size=(2,2)))
modelCNN.add(Flatten())
modelCNN.add(Dense(128, activation='relu'))
modelCNN.add(Dense(actions.shape[0], activation='softmax'))

# %%
#Compile defines the loss function, the optimizer and the metrics. 
modelCNN.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
modelCNN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 256, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 128, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 12, 126, 64)       18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 63, 64)        0
#  2D)
#
#  flatten (Flatten)           (None, 24192)             0
#
#  dense_3 (Dense)             (None, 128)               3096704
#
#  dense_4 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 3,116,294
# Trainable params: 3,116,294
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 800
#checkpoint_dir = f"Logs/{run}/tmp/checkpoint"
model_filename = "Epoch-{epoch:02d}-Loss-{val_loss:.2f}.h5"
checkpoint_filepath = os.path.join('model_CNN/',model_filename)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'Logs/{run}/'+checkpoint_filepath,
    monitor='val_loss', #get the minimum validation loss
    mode='min',
    save_weights_only=True,
    save_best_only=True,
    verbose=2)

# Reference: https://towardsdatascience.com/a-practical-introduction-to-early-stopping-in-machine-learning-550ac88bc8fd
early_stopping =EarlyStopping(monitor='val_loss', patience=20,mode='auto',verbose=2)

# %%
#DO NOT RUN IF DONT WANT TO TRAIN
# Reference: https://www.tensorflow.org/guide/keras/train_and_evaluate
print(f"Fit model on training data for {epochs} epochs")
history_CNN = modelCNN.fit(
    X_train, y_train, 
    #batch_size=64,
    epochs=epochs,
    # We pass some validation data for monitoring validation loss and metrics at the end of each epoch
    validation_data=(X_test, y_test),
    verbose=2,
    batch_size=32,
    callbacks=[tb_callback, model_checkpoint_callback, early_stopping]
)

#https://stats.stackexchange.com/questions/153531/what-is-batch-size-in-neural-network
# Out:
# Fit model on training data for 800 epochs
# Epoch 1/800
#
# Epoch 1: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.2495 - val_categorical_accuracy: 0.9444 - 707ms/epoch - 79ms/step
# Epoch 2/800
#
# Epoch 2: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.2362 - val_categorical_accuracy: 0.9444 - 699ms/epoch - 78ms/step
# Epoch 3/800
#
# Epoch 3: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.2451 - val_categorical_accuracy: 0.9444 - 688ms/epoch - 76ms/step
# Epoch 4/800
#
# Epoch 4: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.2469 - val_categorical_accuracy: 0.9444 - 679ms/epoch - 75ms/step
# Epoch 5/800
#
# Epoch 5: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.2502 - val_categorical_accuracy: 0.9306 - 646ms/epoch - 72ms/step
# Epoch 6/800
#
# Epoch 6: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.2417 - val_categorical_accuracy: 0.9444 - 720ms/epoch - 80ms/step
# Epoch 7/800
#
# Epoch 7: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.2544 - val_categorical_accuracy: 0.9306 - 739ms/epoch - 82ms/step
# Epoch 8/800
#
# Epoch 8: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.2501 - val_categorical_accuracy: 0.9444 - 730ms/epoch - 81ms/step
# Epoch 9/800
#
# Epoch 9: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.2433 - val_categorical_accuracy: 0.9306 - 715ms/epoch - 79ms/step
# Epoch 10/800
#
# Epoch 10: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.2612 - val_categorical_accuracy: 0.9444 - 711ms/epoch - 79ms/step
# Epoch 11/800
#
# Epoch 11: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.2489 - val_categorical_accuracy: 0.9444 - 691ms/epoch - 77ms/step
# Epoch 12/800
#
# Epoch 12: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.2461 - val_categorical_accuracy: 0.9444 - 665ms/epoch - 74ms/step
# Epoch 13/800
#
# Epoch 13: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.2499 - val_categorical_accuracy: 0.9444 - 682ms/epoch - 76ms/step
# Epoch 14/800
#
# Epoch 14: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.2435 - val_categorical_accuracy: 0.9444 - 659ms/epoch - 73ms/step
# Epoch 15/800
#
# Epoch 15: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.2623 - val_categorical_accuracy: 0.9444 - 687ms/epoch - 76ms/step
# Epoch 16/800
#
# Epoch 16: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.2518 - val_categorical_accuracy: 0.9444 - 647ms/epoch - 72ms/step
# Epoch 17/800
#
# Epoch 17: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.2448 - val_categorical_accuracy: 0.9306 - 665ms/epoch - 74ms/step
# Epoch 18/800
#
# Epoch 18: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.2544 - val_categorical_accuracy: 0.9444 - 686ms/epoch - 76ms/step
# Epoch 19/800
#
# Epoch 19: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.2516 - val_categorical_accuracy: 0.9444 - 685ms/epoch - 76ms/step
# Epoch 20/800
#
# Epoch 20: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.2581 - val_categorical_accuracy: 0.9444 - 684ms/epoch - 76ms/step
# Epoch 21/800
#
# Epoch 21: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 0.2548 - val_categorical_accuracy: 0.9306 - 718ms/epoch - 80ms/step
# Epoch 22/800
#
# Epoch 22: val_loss did not improve from 0.18574
# 9/9 - 1s - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.2512 - val_categorical_accuracy: 0.9444 - 708ms/epoch - 79ms/step
# Epoch 22: early stopping

# %% [markdown]
# # 4. GRU Model

# %%
#Set up log directory to monitor training accuracy while training
log_dir = os.path.join('Logs/{}'.format(run))
tb_callback = TensorBoard(log_dir=log_dir)

model_dir = 'Logs/{}/model_GRU'.format(run)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout
from keras.optimizers import Adam

# define the model
modelGRU = Sequential()
modelGRU.add(GRU(64, return_sequences=True, input_shape=(30, 258)))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(128, return_sequences=True))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(64, return_sequences=False))
modelGRU.add(Dense(64, activation='relu'))
modelGRU.add(Dense(32, activation='relu'))
modelGRU.add(Dense(actions.shape[0], activation='softmax'))

# %%
modelGRU.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 30, 64)            62208
#
#  dropout_4 (Dropout)         (None, 30, 64)            0
#
#  gru_4 (GRU)                 (None, 30, 128)           74496
#
#  dropout_5 (Dropout)         (None, 30, 128)           0
#
#  gru_5 (GRU)                 (None, 64)                37248
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 180,390
# Trainable params: 180,390
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile defines the loss function, the optimizer and the metrics. 
modelGRU.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
epochs = 800
#checkpoint_dir = f"Logs/{run}/tmp/checkpoint"
model_filename = "Epoch-{epoch:02d}-Loss-{val_loss:.2f}.h5"
checkpoint_filepath = os.path.join('model_GRU/',model_filename)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'Logs/{run}/'+checkpoint_filepath,
    monitor='val_loss', #get the minimum validation loss
    mode='min',
    save_weights_only=True,
    save_best_only=True,
    verbose=2)

# Reference: https://towardsdatascience.com/a-practical-introduction-to-early-stopping-in-machine-learning-550ac88bc8fd
early_stopping =EarlyStopping(monitor='val_loss', patience=20,mode='auto',verbose=2)

# %%
#DO NOT RUN IF DONT WANT TO TRAIN
# Reference: https://www.tensorflow.org/guide/keras/train_and_evaluate
print(f"Fit model on training data for {epochs} epochs")
history_GRU = modelGRU.fit(
    X_train, y_train, 
    #batch_size=64,
    epochs=epochs,
    # We pass some validation data for monitoring validation loss and metrics at the end of each epoch
    validation_data=(X_test, y_test),
    verbose=2,
    batch_size=32,
    callbacks=[tb_callback, model_checkpoint_callback, early_stopping]
)

#https://stats.stackexchange.com/questions/153531/what-is-batch-size-in-neural-network
# Out:
# Fit model on training data for 800 epochs
# Epoch 1/800
#
# Epoch 1: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0032 - categorical_accuracy: 1.0000 - val_loss: 0.0717 - val_categorical_accuracy: 0.9861 - 275ms/epoch - 31ms/step
# Epoch 2/800
#
# Epoch 2: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.0680 - val_categorical_accuracy: 0.9861 - 255ms/epoch - 28ms/step
# Epoch 3/800
#
# Epoch 3: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.0661 - val_categorical_accuracy: 0.9861 - 251ms/epoch - 28ms/step
# Epoch 4/800
#
# Epoch 4: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.0624 - val_categorical_accuracy: 0.9861 - 269ms/epoch - 30ms/step
# Epoch 5/800
#
# Epoch 5: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 0.0605 - val_categorical_accuracy: 0.9861 - 253ms/epoch - 28ms/step
# Epoch 6/800
#
# Epoch 6: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.0653 - val_categorical_accuracy: 0.9861 - 246ms/epoch - 27ms/step
# Epoch 7/800
#
# Epoch 7: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.0692 - val_categorical_accuracy: 0.9861 - 252ms/epoch - 28ms/step
# Epoch 8/800
#
# Epoch 8: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.0700 - val_categorical_accuracy: 0.9861 - 249ms/epoch - 28ms/step
# Epoch 9/800
#
# Epoch 9: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.0716 - val_categorical_accuracy: 0.9861 - 251ms/epoch - 28ms/step
# Epoch 10/800
#
# Epoch 10: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.0708 - val_categorical_accuracy: 0.9861 - 254ms/epoch - 28ms/step
# Epoch 11/800
#
# Epoch 11: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.0709 - val_categorical_accuracy: 0.9861 - 248ms/epoch - 28ms/step
# Epoch 12/800
#
# Epoch 12: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.0691 - val_categorical_accuracy: 0.9861 - 237ms/epoch - 26ms/step
# Epoch 13/800
#
# Epoch 13: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.0656 - val_categorical_accuracy: 0.9861 - 249ms/epoch - 28ms/step
# Epoch 14/800
#
# Epoch 14: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.0630 - val_categorical_accuracy: 0.9861 - 249ms/epoch - 28ms/step
# Epoch 15/800
#
# Epoch 15: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.0665 - val_categorical_accuracy: 0.9861 - 253ms/epoch - 28ms/step
# Epoch 16/800
#
# Epoch 16: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.0663 - val_categorical_accuracy: 0.9861 - 245ms/epoch - 27ms/step
# Epoch 17/800
#
# Epoch 17: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.0696 - val_categorical_accuracy: 0.9861 - 255ms/epoch - 28ms/step
# Epoch 18/800
#
# Epoch 18: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0695 - val_categorical_accuracy: 0.9861 - 247ms/epoch - 27ms/step
# Epoch 19/800
#
# Epoch 19: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0680 - val_categorical_accuracy: 0.9861 - 271ms/epoch - 30ms/step
# Epoch 20/800
#
# Epoch 20: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0685 - val_categorical_accuracy: 0.9861 - 257ms/epoch - 29ms/step
# Epoch 21/800
#
# Epoch 21: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0655 - val_categorical_accuracy: 0.9861 - 257ms/epoch - 29ms/step
# Epoch 22/800
#
# Epoch 22: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.0659 - val_categorical_accuracy: 0.9861 - 237ms/epoch - 26ms/step
# Epoch 23/800
#
# Epoch 23: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0676 - val_categorical_accuracy: 0.9861 - 252ms/epoch - 28ms/step
# Epoch 24/800
#
# Epoch 24: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 0.0678 - val_categorical_accuracy: 0.9861 - 237ms/epoch - 26ms/step
# Epoch 25/800
#
# Epoch 25: val_loss did not improve from 0.05496
# 9/9 - 0s - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 0.0659 - val_categorical_accuracy: 0.9861 - 270ms/epoch - 30ms/step
# Epoch 25: early stopping

# %%
# plot the results
plt.plot(history_LSTM.history['categorical_accuracy'], label='LSTM Accuracy')
plt.plot(history_CNN.history['categorical_accuracy'], label='CNN Accuracy')
plt.plot(history_GRU.history['categorical_accuracy'], label='GRU Accuracy')
plt.legend()
plt.show()

plt.plot(history_LSTM.history['val_loss'], label='LSTM Validation Loss')
plt.plot(history_CNN.history['val_loss'], label='CNN Validation Loss')
plt.plot(history_GRU.history['val_loss'], label='GRU Validation Loss')
plt.legend()
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yasmi\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # 5. View Training Logs

# %%
log_dir
# Out:
# 'Logs/run'

# %%
# Display Training Logs in Tensorboard 
# %load_ext tensorboard
# %tensorboard --logdir {log_dir}
# Out:
#       <iframe id="tensorboard-frame-48e97597c0e719e1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-48e97597c0e719e1");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # 6. Plot Training Results

# %%
import pandas as pd
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

hist_df.to_csv(f'./Logs/{run}/history.csv',index = False)

df_hist = pd.read_csv(f'./Logs/{run}/history.csv')
hist_df
# Out:
#         loss  categorical_accuracy  val_loss  val_categorical_accuracy
# 0   1.208246              0.468750  1.079988                  0.527778
# 1   0.981737              0.604167  0.946922                  0.583333
# 2   0.851998              0.673611  0.856221                  0.694444
# 3   0.800007              0.659722  0.897425                  0.569444
# 4   0.703299              0.715278  0.761566                  0.680556
# 5   0.622012              0.756944  0.888735                  0.680556
# 6   0.574974              0.770833  0.725455                  0.708333
# 7   0.554200              0.795139  0.875303                  0.611111
# 8   0.492484              0.791667  0.775234                  0.638889
# 9   0.442273              0.847222  0.728944                  0.652778
# 10  0.345321              0.885417  0.651736                  0.777778
# 11  0.304670              0.916667  0.633057                  0.777778
# 12  0.244925              0.934028  0.533450                  0.847222
# 13  0.241494              0.916667  0.611300                  0.805556
# 14  0.205529              0.944444  0.538966                  0.819444
# 15  0.171263              0.951389  0.749059                  0.722222
# 16  0.211549              0.920139  0.553115                  0.805556
# 17  0.177153              0.934028  0.562934                  0.833333
# 18  0.113427              0.989583  0.430777                  0.902778
# 19  0.085741              0.982639  0.478043                  0.875000
# 20  0.089873              0.982639  0.403460                  0.888889
# 21  0.092712              0.975694  0.447401                  0.861111
# 22  0.072620              1.000000  0.388975                  0.916667
# 23  0.059193              0.993056  0.431120                  0.902778
# 24  0.064845              0.982639  0.438091                  0.861111
# 25  0.048850              0.993056  0.454091                  0.875000
# 26  0.044698              0.993056  0.423207                  0.930556
# 27  0.039750              1.000000  0.370074                  0.930556
# 28  0.033690              0.996528  0.374781                  0.902778
# 29  0.032869              0.996528  0.366255                  0.930556
# 30  0.026127              0.996528  0.437589                  0.888889
# 31  0.020704              1.000000  0.359679                  0.930556
# 32  0.026720              1.000000  0.379497                  0.930556
# 33  0.014122              1.000000  0.370466                  0.930556
# 34  0.013661              1.000000  0.384942                  0.930556
# 35  0.012816              1.000000  0.363331                  0.930556
# 36  0.011128              1.000000  0.361994                  0.930556
# 37  0.009111              1.000000  0.364449                  0.944444
# 38  0.009144              1.000000  0.369855                  0.944444
# 39  0.009815              1.000000  0.390382                  0.930556
# 40  0.008999              1.000000  0.360416                  0.930556
# 41  0.007794              1.000000  0.367323                  0.930556
# 42  0.007588              1.000000  0.402248                  0.930556
# 43  0.009019              1.000000  0.369004                  0.930556
# 44  0.005872              1.000000  0.390033                  0.930556
# 45  0.004961              1.000000  0.376073                  0.930556
# 46  0.004541              1.000000  0.376676                  0.930556
# 47  0.004309              1.000000  0.390619                  0.930556
# 48  0.004293              1.000000  0.386470                  0.930556
# 49  0.003912              1.000000  0.376840                  0.930556
# 50  0.003490              1.000000  0.381230                  0.930556
# 51  0.003324              1.000000  0.381868                  0.930556

# %%
min_loss_epoch = hist_df[hist_df['loss']==min(hist_df['loss'])].index.values
min_loss = min(hist_df['loss'])
print('Index of Minimum Loss =',min_loss_epoch[0])
print('Minimum Loss =',round(min_loss,2))
# Out:
# Index of Minimum Loss = 51
# Minimum Loss = 0.0

# %%
# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Training and Validation Categorical Accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig(f'{img_dir}/Model Training and Validation Categorical Accuracy.jpg')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Training and Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig(f'{img_dir}/Model Training and Validation Loss.jpg')
plt.show()

# %% [markdown]
# # 6. Load Best Model Weights/Checkpoint

# %%
#PATH: "C:\Users\yasmi\Desktop\data science\Logs\run_version2training\model\Epoch-72-Loss-0.15.h5"

model.load_weights('C:/Users/yasmi/Desktop/data science/Logs/run_version2training/model3/Epoch-64-Loss-0.05.h5')

# %% [markdown]
# # 7. Make Predictions on X_test

# %%
res = model.predict(X_test)

# Get y_predict and apply softmax function
np.argmax(res[6])
# Out:
# 3/3 [==============================] - 0s 10ms/step
# 1

# %%
# Predicted Action
actions[np.argmax(res[4])]
# Out:
# 'no'

# %%
# Actual Action
actions[np.argmax(y_test[4])]
# Out:
# 'no'

# %%
actions[y_test[1]]
# Out:
# array(['no', 'no', 'no', 'no', 'please', 'no'], dtype='<U8')

# %% [markdown]
# # 8. Model Evaluation (Categorical Accuracy and Confusion Matrix)
# Running these cells converts the predicition from their one-hot encoded representation to a categorical label e.g. 0,1 or 2 as opoosed to [1,0,0], [0,1,0] or [0,0,1].

# %%
X_test.shape
# Out:
# (72, 30, 258)

# %%
label_list = ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']
label_list
# Out:
# ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']

# %%
label_list = list(label_map.keys())
label_list
# Out:
# ['no', 'please', 'thanks', 'welcome', 'yes', 'noaction']

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

def generate_confusion_matrix_accuracy(X,y,types):
    predictions = model.predict(X)
    y_true = np.argmax(y, axis=1)
    y_pred = np.argmax(predictions, axis=1)
    cm = confusion_matrix(y_true, y_pred)

    print(f'{types} Overall Multiclassification Accuracy Score across all classes:',round(accuracy_score(y_true, y_pred),2))

    sns.heatmap(cm, xticklabels = label_list, yticklabels = label_list, annot = True, linewidths = 0.1, fmt='d',cmap='Blues') # cmap = 'YlGnBu')
    plt.title(f"{types} Confusion matrix", fontsize = 15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
generate_confusion_matrix_accuracy(X_train,y_train,'Train')
# Out:
# 9/9 [==============================] - 0s 12ms/step
# Train Overall Multiclassification Accuracy Score across all classes: 1.0

# %%
generate_confusion_matrix_accuracy(X_test,y_test,'Test')
# Out:
# 3/3 [==============================] - 0s 10ms/step
# Test Overall Multiclassification Accuracy Score across all classes: 0.99

# %% [markdown]
# # 9. Run Real Time Keypoint Detection Model Using Webcam

# %%
colors = [(245,221,173), (245,185,265), (146,235,193),(204,152,295),(255,217,179),(0,0,179)]

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables

#collect 30 frames
sequence = []

#concantenate 
sentence = []

#confident matrix
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 21ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 19ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# noaction
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 20ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# thanks
